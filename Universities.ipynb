# %% [markdown]
# <a href="https://colab.research.google.com/github/harika010/pandas_viz_repository/blob/main/Universities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sn

# %%
df = pd.read_csv('Universities.csv')

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
df.tail()
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96

# %%
df.head(10)
# Out:
#            Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0         Brown  1310     89      22       13     22704        94
# 1       CalTech  1415    100      25        6     63575        81
# 2           CMU  1260     62      59        9     25026        72
# 3      Columbia  1310     76      24       12     31510        88
# 4       Cornell  1280     83      33       13     21864        90
# 5     Dartmouth  1340     89      23       10     32162        95
# 6          Duke  1315     90      30       12     31585        95
# 7    Georgetown  1255     74      24       12     20126        92
# 8       Harvard  1400     91      14       11     39525        97
# 9  JohnsHopkins  1305     75      44        7     58691        87

# %%
df.tail(10)
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 15      Purdue  1005     28      90       19      9066        69
# 16    Stanford  1360     90      20       12     36450        93
# 17    TexasA&M  1075     49      67       25      8704        67
# 18  UCBerkeley  1240     95      40       17     15140        78
# 19    UChicago  1290     75      50       13     38380        87
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96

# %%
df[['SAT','Accept']].mean()
# Out:
# SAT       1266.44
# Accept      39.20
# dtype: float64

# %%
df.isnull()
# Out:
#      Univ    SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0   False  False  False   False    False     False     False
# 1   False  False  False   False    False     False     False
# 2   False  False  False   False    False     False     False
# 3   False  False  False   False    False     False     False
# 4   False  False  False   False    False     False     False
# 5   False  False  False   False    False     False     False
# 6   False  False  False   False    False     False     False
# 7   False  False  False   False    False     False     False
# 8   False  False  False   False    False     False     False
# 9   False  False  False   False    False     False     False
# 10  False  False  False   False    False     False     False
# 11  False  False  False   False    False     False     False
# 12  False  False  False   False    False     False     False
# 13  False  False  False   False    False     False     False
# ...

# %%
df[df['SAT']>1200]
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df.shape
# Out:
# (25, 7)

# %%
df.columns
# Out:
# Index(['Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
df[['SAT','Accept','Top10','SFRatio','Expenses','GradRate']].mean()
# Out:
# SAT          1266.44
# Accept         39.20
# Top10          76.48
# SFRatio        12.72
# Expenses    27388.00
# GradRate       86.72
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# SAT          1285.0
# Top10          81.0
# Accept         36.0
# SFRatio        12.0
# Expenses    27553.0
# GradRate       90.0
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#        SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0   1255.0   75.0    14.0     11.0      8704      95.0
# 1   1260.0   89.0    24.0     12.0      9066       NaN
# 2   1310.0   90.0    30.0     13.0     10185       NaN
# 3   1375.0   91.0    44.0      NaN     11857       NaN
# 4      NaN   95.0     NaN      NaN     13349       NaN
# 5      NaN    NaN     NaN      NaN     15122       NaN
# 6      NaN    NaN     NaN      NaN     15140       NaN
# 7      NaN    NaN     NaN      NaN     15470       NaN
# 8      NaN    NaN     NaN      NaN     20126       NaN
# 9      NaN    NaN     NaN      NaN     21864       NaN
# 10     NaN    NaN     NaN      NaN     22704       NaN
# 11     NaN    NaN     NaN      NaN     25026       NaN
# 12     NaN    NaN     NaN      NaN     27553       NaN
# 13     NaN    NaN     NaN      NaN     28052       NaN
# 14     NaN    NaN     NaN      NaN     30220       NaN
# 15     NaN    NaN     NaN      NaN     31510       NaN
# ...

# %%
df.var(numeric_only=True)
# Out:
# SAT         1.174184e+04
# Top10       3.776767e+02
# Accept      3.891667e+02
# SFRatio     1.654333e+01
# Expenses    2.080773e+08
# GradRate    8.204333e+01
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# SAT           108.359771
# Top10          19.433905
# Accept         19.727308
# SFRatio         4.067350
# Expenses    14424.883165
# GradRate        9.057778
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# SAT        -0.950910
# Top10      -1.219756
# Accept      0.867538
# SFRatio     1.120719
# Expenses    0.852350
# GradRate   -0.999521
# dtype: float64

# %%
df.kurt(numeric_only=True)
# Out:
# SAT         0.355122
# Top10       0.700307
# Accept      0.252908
# SFRatio     2.353743
# Expenses    0.638162
# GradRate   -0.164740
# dtype: float64

# %%
pd.set_option('Display.max_rows',None)

# %%
df.isnull().sum()
# Out:
# Univ        0
# SAT         0
# Top10       0
# Accept      0
# SFRatio     0
# Expenses    0
# GradRate    0
# dtype: int64

# %%
df.min(numeric_only=True)
# Out:
# SAT         1005
# Top10         28
# Accept        14
# SFRatio        6
# Expenses    8704
# GradRate      67
# dtype: int64

# %%
df.max(numeric_only=True)
# Out:
# SAT          1415
# Top10         100
# Accept         90
# SFRatio        25
# Expenses    63575
# GradRate       97
# dtype: int64

# %%
plt.hist(df['GradRate'])
plt.xlabel("GradRate")
plt.ylabel("Frequency")
plt.title("Universities")
plt.figure(figsize=(5,5))
plt.show()

# %%
sn.histplot([df["SAT"]])
# Out:
# <Axes: ylabel='Count'>

# %%
sn.pairplot(df.iloc[:,1:5])

# %%
sn.distplot(df['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
plt.plot(df['SAT'],df['Accept'],'yo')

# %%
sn.pairplot(df)

# %%
plt.boxplot(df["Accept"])
plt.xlabel('Accept')
plt.ylabel('Count')
plt.title('BOXPLOT')
plt.show()
plt.figure(figsize=(5,5))

# %%
sn.pairplot(df.iloc[:,:])
